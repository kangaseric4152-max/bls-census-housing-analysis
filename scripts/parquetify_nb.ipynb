# %%
from bls_housing.pipeline.duck import get_analysis_db_connection

con = get_analysis_db_connection()

df = con.sql("""
    select * from bls_raw_manifest where year = 2019 limit 10
        """).df()
print(df)

con.close()
